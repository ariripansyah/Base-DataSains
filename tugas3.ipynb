# %%
import matplotlib.pyplot as plt

# %%
print('    =====soal 1=====')
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
pendidikan =['Paskibara','Pmr','Pramuka', 'Futsal', 'voly', 'kesenian', 'rohis']
jumlah_orang =[5, 18, 30, 7, 16, 19, 12]
plt.title("Ekskul kelas 10")                                                                           
c = ['red','green','blue']              
plt.bar(pendidikan, jumlah_orang, color = c)
plt.show()
# Out:
#     =====soal 1=====

# %%
print('    =====soal 2=====')
a = 5
b = 21
c = 6
hasil = (a + b + c)
print('maka jumlah hasil ' + str(hasil))

a = 18
b = 4  
c = 12 
hasil = (a + b + c)
print('maka jumlah hasil ' + str(hasil))

a = 30
b = 8
c = 24
hasil = (a + b + c)
print('maka jumlah hasil ' + str(hasil))

a = 7
b = 29
c = 15
hasil = (a + b + c)
print('maka jumlah hasil ' + str(hasil))

a = 16
b = 10
c = 12
hasil = (a + b + c)
print('maka jumlah hasil ' + str(hasil))

a = 19
b = 18
c = 4
hasil = (a + b + c)
print('maka jumlah hasil ' + str(hasil))

a = 17
b = 8
c = 20
hasil = (a + b + c)
print('maka jumlah hasil ' + str(hasil))

fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
Paskibra =['Paskibara','Pmr','Pramuka', 'Futsal', 'voly', 'Kesenian', 'rohis']
jumlah_orang =[5, 18, 30, 7, 16, 19, 12]
plt.title("Ekskul kelas 10")
c = ['red','green','blue']
plt.bar(Paskibra, jumlah_orang, color = c)
plt.show()
# Out:
#     =====soal 2=====
# maka jumlah hasil 32
# maka jumlah hasil 34
# maka jumlah hasil 62
# maka jumlah hasil 51
# maka jumlah hasil 38
# maka jumlah hasil 41
# maka jumlah hasil 45

# %%
print('     =====soal 3===')
a = 51
b = 38
hasil_o = (a + b)
print("hasil olahraga = " + str(hasil_o))
print("")

a = 32
b = 34
c = 62
d = 41
e = 29
hasil_s = (a + b + c + e)
print("hasil semua = " + str(hasil_s))
print("")

a = 17
b = 8
c = 20
hasil_td = (a + b + c)
print("hasil yang tidak mengikuti = " + str(hasil_td))
print("")

print("diagram batang")
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
Ekskul =['olahraga', 'megikuti', 'tidak mengikuti']
jumlah =[89, 157, 45]
plt.title("Jumlah Siswa")
c = ['red','green','blue']
plt.bar(Ekskul, jumlah, color = c)
plt.show()
print("")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title('Data Siswa PPD SMK AL-MADANI')
Ekskul =['olahraga', 'megikuti', 'tidak mengikuti']
jumlah =[89, 157, 45]
ax.pie(jumlah,labels=Ekskul,autopct='%1.2f%%')
plt.show()
# Out:
#      =====soal 3===
# hasil olahraga = 89
#
# hasil semua = 157
#
# hasil yang tidak mengikuti = 45
#
# diagram batang

# %%
print('    =====soal 4=====')
a = 17
b = 8
c = 28
hasil_a = a/45
hasil_b = b/45
hasil_c = c/45
hasil_td = (a + b) + (c)
print("yang tidak mengikuti = " + str(hasil_td))
print("")
print("hasil A = " + str(hasil_a))
print("hasil B = " + str(hasil_b))
print("hasil C = " + str(hasil_c))
print("hasil td  = " + str(hasil_td))
# Out:
#     =====soal 4=====
# yang tidak mengikuti = 53
#
# hasil A = 0.37777777777777777
# hasil B = 0.17777777777777778
# hasil C = 0.6222222222222222
# hasil td  = 53
