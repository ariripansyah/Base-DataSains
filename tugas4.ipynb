# %%
import statistics 
import pandas as pd
import numpy as np
from scipy import stats

# %%
burger = 24000
pizza = 52000
dimsum = 30000
ekkado = 7500
milkshake = 10000
eskrim = 15000

print('    ======soal 1=======')
burger_1 = 6
pizza_2 = 3
dimsum_3 = 4
ekkado_4 = 4
milkshake_5 = 2
eskrim_6 = 5
jm = (burger_1 * burger) + (pizza_2 * pizza) + (dimsum_3 * dimsum) + (ekkado_4 * ekkado) + (milkshake_5 * milkshake) + (eskrim_6 * eskrim)
h1 = burger_1 + pizza_2 + dimsum_3 + ekkado_4 + milkshake_5 + eskrim_6
print('maka jumlahnya yang dipesan ' + str(jm))
print('maka jumlah harganya adalah ' + str(h1))
print('')
print('     ===== soal 2=====')
jm = (burger_1 + pizza_2 + dimsum_3 + ekkado_4 + milkshake_5 + eskrim_6)
f1 = burger_1 / jm * 100
f2 = pizza_2 / jm * 100
f3 = dimsum_3 / jm * 100
f4 = ekkado_4 / jm * 100
f5 = milkshake_5 /jm * 100
f6 = eskrim_6 / jm *100
print('burger_1 ' + str(f1))
print('pizza_2 ' + str(f2))
print('dimsum_3 ' + str(f3))
print('ekkado_4 ' + str(f4))
print('milkshake_5 ' + str(f5))
print('eskrim_6 ' + str(f6))
print('')
#pie char
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("JUMLAH HARGA")
jurusan = ['burger_1','pizza_2','dimsum_3','ekkado_4','milkshake_5','eskrim_6']
siswa = [24.0, 12.0, 16.666666666666664, 16.666666666666664, 8.333333333333332, 20.833333333333336]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print('    ======soal 3=======')
print('ahmad')
ba = 4
pa = 2
ja = 7.5
jm1 = (0.70 *((ba * 24000) + (pa * 52000)) + (7.5 * 2000)) - 5000
print('maka jumlah ahmad: ' + str(jm1))
ka = (200000 - jm1)
print('maka jumlah kembalian ahmad: ' + str(ka))
print('beni')
db = 3
eb = 1
mb = 2
jb = 4
jm2 = (0.70 * ((db * 30000) + (eb * 15000) + (mb * 10000))) + (jb * 1800) - 5000
print('maka total belanjaan beni adalah:' + str(jm2))
kb = (150000 - jm2)
print('maka jumlah kembalian beni: ' + str(kb))
print('citra')
ec = 3
jc = 8
jm3 = (ec * 15000) + (jc * 2000) - 5000
print('maka total belanjaan citra adalah: ' + str(jm3))
kc = (60000 - jm3)
print('maka jumlah kembaian citra: ' + str(kc))
print('dadang')
bd = 2
dd = 1
je = 5
jm4 = (0.80 * ((bd * 24000) + (dd * 30000))) + (je * 1800) - 5000
print('maka total belanjaan dadang adalah:' + str(jm4))
kd = (100000 - jm4)
print('maka jumlah kembalian dadang:' + str(kd))
print('epen')
de = 4
es = 1
pe = 1
jm5 = (0.70 * ((de * 7500) + (es * 15000) + (pe * 52000))) + (12 * 2200) - 5000
print('maka total belanjaan epen adalah:' + str(jm5))
kde = (100000 - jm5)
print('maka jumlah epen ' + str(kde))
print('')
print('    =====soal 4====')
print('ahmad')
burger_ahmad = 4
pizza_ahmad = 2
hasil = (0.30 * ((burger_ahmad * 24000) + (pizza_ahmad * 52000))) + 5000
print('maka jumlah potongan ahmad adalah: Rp.' + str(hasil))

dimsum_beni = 3
eskrim_beni = 1
milkshake_beni = 2
jarak_beni = 4
hasil = (0.30 * ((dimsum_beni * 30000) + (eskrim_beni * 15000) + (milkshake_beni * 10000))) + 5000
print('maka jumlah potongan beni adalah: Rp.' + str(hasil))

eskrim_citra = 4
hasil = (0 * ((eskrim_citra * 15000))) + 5000
print('maka jumlah potongan citra adalah: Rp.' + str(hasil))

burger_dadang = 2
dimsum_dadang = 1
hasil = (0.20 * ((burger_dadang * 24000) + (dimsum_dadang * 30000))) + 5000
print('maka jumlah potongan dadang adalah: Rp.' + str(hasil))

ekkado_epen = 4
eskrim_epen = 1
pizza_epen = 1
hasil = (0.30 * ((ekkado_epen * 7500) + (eskrim_epen * 15000) + (pizza_epen * 52000))) + 5000
print('maka jumlah potongan epen adalah: Rp.' + str(hasil))

print('    =====soal 5=====')

a = 7.5
b = 2000
c = 4
d = 1800
e = 8
f = 2000
g = 5
h = 1800
i = 12
j = 2200
jm = (a * b) + (c * d) + (e * f) + (g * h) + (i * j)
print('maka jarak dan ongkir adalah: ' + str(jm))
# Out:
#     ======soal 1=======
# maka jumlahnya yang dipesan 545000
# maka jumlah harganya adalah 24
#
#      ===== soal 2=====
# burger_1 25.0
# pizza_2 12.5
# dimsum_3 16.666666666666664
# ekkado_4 16.666666666666664
# milkshake_5 8.333333333333332
# eskrim_6 20.833333333333336
#     ======soal 3=======
# ahmad
# maka jumlah ahmad: 150000.0
# maka jumlah kembalian ahmad: 50000.0
# beni
# maka total belanjaan beni adalah:89700.0
# maka jumlah kembalian beni: 60300.0
# citra
# maka total belanjaan citra adalah: 56000
# maka jumlah kembaian citra: 4000
# dadang
# maka total belanjaan dadang adalah:66400.0
# maka jumlah kembalian dadang:33600.0
# epen
# maka total belanjaan epen adalah:89300.0
# maka jumlah epen 10700.0
#
#     =====soal 4====
# ahmad
# maka jumlah potongan ahmad adalah: Rp.65000.0
# maka jumlah potongan beni adalah: Rp.42500.0
# maka jumlah potongan citra adalah: Rp.5000
# maka jumlah potongan dadang adalah: Rp.20600.0
# maka jumlah potongan epen adalah: Rp.34100.0
# ...
